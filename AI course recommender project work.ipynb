# %% [markdown]
# <a href="https://colab.research.google.com/github/Chandrani45/AI-COURSE-RECOMMENDER-PROJECT-WORK-/blob/main/Chandrani_Sengupta_project_UIfix_2026_07_25.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# LOADING THE LIBRARIES

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# !pip install groq
# Out:
# Requirement already satisfied: groq in /usr/local/lib/python3.12/dist-packages (1.6.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from groq) (4.14.2)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from groq) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from groq) (0.28.1)
# Requirement already satisfied: pydantic<3,>=1.9.0 in /usr/local/lib/python3.12/dist-packages (from groq) (2.13.4)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from groq) (1.3.1)
# Requirement already satisfied: typing-extensions<5,>=4.14 in /usr/local/lib/python3.12/dist-packages (from groq) (4.16.0)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->groq) (3.18)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (2026.6.17)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->groq) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->groq) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.7.0)
# Requirement already satisfied: pydantic-core==2.46.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (2.46.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3,>=1.9.0->groq) (0.4.2)

# %% [markdown]
# MODULE 0
# Loading Groq

# %%
import os
from groq import Groq

# %%
import os
from getpass import getpass

os.environ["GROQ_API_KEY"] = getpass("Enter your Groq API key: ")
# Out:
# Enter your Groq API key: ··········

# %%
client = Groq()

response = client.chat.completions.create(
    model="llama-3.3-70b-versatile",
    messages=[
        {"role": "system", "content": "You are a concise assistant."},
        {"role": "user", "content": "Explain why Groq's inference is fast in 3 sentences."},
    ],
)

print(response.choices[0].message.content)
# Out:
# Groq's inference is fast due to its tensor processing unit (TPU) architecture, which is specifically designed for machine learning workloads. The TPU's systolic array enables efficient matrix multiplication, a key operation in neural networks, allowing for rapid processing of complex models. Additionally, Groq's compiler and software optimizations further accelerate inference by minimizing overhead and maximizing utilization of the TPU's capabilities.

# %% [markdown]
# LOADING THE COURSE DATASET

# %%
course=pd.read_csv('/content/coursera_course_dataset_v3.csv')

# %% [markdown]
# PRINTING THE FIRST 5 ROWS

# %%
course.head()
# Out:
#    Unnamed: 0                                  Title Organization  \
# 0           0                   Google Cybersecurity       Google
# 1           1                  Google Data Analytics       Google
# 2           3             Google Project Management:       Google
# 3           4                       IBM Data Science          IBM
# 4           5  Google Digital Marketing & E-commerce       Google
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# 2   Project Management, Strategy and Operations, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 1  https://www.coursera.org/professional-certific...                  229,865
# 2  https://www.coursera.org/professional-certific...                   29,702
# 3  https://www.coursera.org/professional-certific...                  239,622
# 4  https://www.coursera.org/professional-certific...                  384,238
#
#                                   course_description Review Count Difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# 1  Prepare for a new career in the high-growth fi...         137K   Beginner
# 2  Prepare-se para uma nova carreira no campo de ...         100K   Beginner
# 3  Prepare for a career in the high-growth field ...         120K   Beginner
# 4  This course is the eighth course in the Google...          23K   Beginner
#
#                        Type      Duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months
# 2  Professional Certificate  3 - 6 Months
# 3  Professional Certificate  3 - 6 Months
# 4  Professional Certificate  3 - 6 Months

# %% [markdown]
# We drop the unnamed column as it is of no use

# %%
course.rename(columns={'Unnamed: 0':'Course_id'},inplace=True)

# %%
course.head()
# Out:
#    Course_id                                  Title Organization  \
# 0          0                   Google Cybersecurity       Google
# 1          1                  Google Data Analytics       Google
# 2          3             Google Project Management:       Google
# 3          4                       IBM Data Science          IBM
# 4          5  Google Digital Marketing & E-commerce       Google
#
#                                               Skills  Ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# 2   Project Management, Strategy and Operations, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 1  https://www.coursera.org/professional-certific...                  229,865
# 2  https://www.coursera.org/professional-certific...                   29,702
# 3  https://www.coursera.org/professional-certific...                  239,622
# 4  https://www.coursera.org/professional-certific...                  384,238
#
#                                   course_description Review Count Difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# 1  Prepare for a new career in the high-growth fi...         137K   Beginner
# 2  Prepare-se para uma nova carreira no campo de ...         100K   Beginner
# 3  Prepare for a career in the high-growth field ...         120K   Beginner
# 4  This course is the eighth course in the Google...          23K   Beginner
#
#                        Type      Duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months
# 2  Professional Certificate  3 - 6 Months
# 3  Professional Certificate  3 - 6 Months
# 4  Professional Certificate  3 - 6 Months

# %%
course.columns
# Out:
# Index(['Course_id', 'Title', 'Organization', 'Skills', 'Ratings', 'course_url',
#        'course_students_enrolled', 'course_description', 'Review Count',
#        'Difficulty', 'Type', 'Duration'],
#       dtype='object')

# %%
course.columns=course.columns.str.lower()

# %%
course.head()
# Out:
#    course_id                                  title organization  \
# 0          0                   Google Cybersecurity       Google
# 1          1                  Google Data Analytics       Google
# 2          3             Google Project Management:       Google
# 3          4                       IBM Data Science          IBM
# 4          5  Google Digital Marketing & E-commerce       Google
#
#                                               skills  ratings  \
# 0   Network Security, Python Programming, Linux, ...      4.8
# 1   Data Analysis, R Programming, SQL, Business C...      4.8
# 2   Project Management, Strategy and Operations, ...      4.8
# 3   Python Programming, Data Science, Machine Lea...      4.6
# 4   Digital Marketing, Marketing, Marketing Manag...      4.8
#
#                                           course_url course_students_enrolled  \
# 0  https://www.coursera.org/professional-certific...                  700,909
# 1  https://www.coursera.org/professional-certific...                  229,865
# 2  https://www.coursera.org/professional-certific...                   29,702
# 3  https://www.coursera.org/professional-certific...                  239,622
# 4  https://www.coursera.org/professional-certific...                  384,238
#
#                                   course_description review count difficulty  \
# 0  Google Cloud Fundamentals: Core Infrastructure...          20K   Beginner
# 1  Prepare for a new career in the high-growth fi...         137K   Beginner
# 2  Prepare-se para uma nova carreira no campo de ...         100K   Beginner
# 3  Prepare for a career in the high-growth field ...         120K   Beginner
# 4  This course is the eighth course in the Google...          23K   Beginner
#
#                        type      duration
# 0  Professional Certificate  3 - 6 Months
# 1  Professional Certificate  3 - 6 Months
# 2  Professional Certificate  3 - 6 Months
# 3  Professional Certificate  3 - 6 Months
# 4  Professional Certificate  3 - 6 Months

# %%
#print rows and columns
course.shape
# Out:
# (623, 12)

# %% [markdown]
# The data has 623 rows and 11 columns

# %%
role_skills={'Data Scientist': ['python', 'statistics', 'machine learning', 'sql',
                           'data visualization', 'deep learning'], 'Data Analyst': ['excel', 'sql', 'statistics', 'data visualization', 'python'], 'ML Engineer':['python', 'machine learning', 'deep learning', 'sql', 'cloud'],'Data Engineer': ['python','sql', 'data wrangling', 'cloud', 'big data', 'apis'], 'Business Analyst': ['excel', 'sql', 'statistics', 'data visualization',
                           'communication'],'BI Developer': ['sql', 'data visualization', 'excel', 'statistics', 'power bi'],'AI Researcher':['python', 'deep learning', 'machine learning',
                           'mathematics', 'nlp'], 'Backend Developer': ['python', 'sql', 'apis', 'cloud', 'git'],'MLOps Engineer':['python', 'machine learning', 'cloud', 'docker', 'mlops'], 'NLP Engineer':['python', 'machine learning', 'deep learning', 'nlp',
                           'statistics']



}

# %%
role_skills['Data Scientist']
# Out:
# ['python',
#  'statistics',
#  'machine learning',
#  'sql',
#  'data visualization',
#  'deep learning']

# %%
course.isnull().sum()
# Out:
# course_id                     0
# title                         0
# organization                  0
# skills                        0
# ratings                       0
# course_url                  220
# course_students_enrolled    236
# course_description          221
# review count                  0
# difficulty                    0
# type                          0
# duration                      0
# dtype: int64

# %%
course.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicates as such

# %%
course.drop(columns=['organization','ratings','course_url' ,	'course_students_enrolled' ,'course_description', 'review count','difficulty','type','duration'],axis=1,inplace=True)

# %%
course.isnull().sum()
# Out:
# course_id    0
# title        0
# skills       0
# dtype: int64

# %%
course.head()
# Out:
#    course_id                                  title  \
# 0          0                   Google Cybersecurity
# 1          1                  Google Data Analytics
# 2          3             Google Project Management:
# 3          4                       IBM Data Science
# 4          5  Google Digital Marketing & E-commerce
#
#                                               skills
# 0   Network Security, Python Programming, Linux, ...
# 1   Data Analysis, R Programming, SQL, Business C...
# 2   Project Management, Strategy and Operations, ...
# 3   Python Programming, Data Science, Machine Lea...
# 4   Digital Marketing, Marketing, Marketing Manag...

# %%
course.shape
# Out:
# (623, 3)

# %%
#cleaning the skills dataset
import re
def clean(text):
  return re.sub(r'[^a-z0-9]','',text.str.lower())
  return re.sub(r'\s+',"",text).strip()

# %%
import re

def clean(s):
    s = re.sub(r"[^a-z0-9 ]", " ", str(s).lower())
    return re.sub(r"\s+", " ", s).strip()

# build the search text from Title + Skills  (note the " " between them)
course['text'] = (course['title'] + " " + course['skills']).apply(clean)

# keep a clean LIST of skills — M6 needs this
course['skills'] = course['skills'].fillna("").apply(
    lambda s: [x.strip().lower() for x in str(s).split(",") if x.strip()])

course[['course_id', 'title', 'skills', 'text']].head(3)
# Out:
#    course_id                       title  \
# 0          0        Google Cybersecurity
# 1          1       Google Data Analytics
# 2          3  Google Project Management:
#
#                                               skills  \
# 0  [network security, python programming, linux, ...
# 1  [data analysis, r programming, sql, business c...
# 2  [project management, strategy and operations, ...
#
#                                                 text
# 0  google cybersecurity network security python p...
# 1  google data analytics data analysis r programm...
# 2  google project management project management s...

# %%
course.head()
# Out:
#    course_id                                  title  \
# 0          0                   Google Cybersecurity
# 1          1                  Google Data Analytics
# 2          3             Google Project Management:
# 3          4                       IBM Data Science
# 4          5  Google Digital Marketing & E-commerce
#
#                                               skills  \
# 0  [network security, python programming, linux, ...
# 1  [data analysis, r programming, sql, business c...
# 2  [project management, strategy and operations, ...
# 3  [python programming, data science, machine lea...
# 4  [digital marketing, marketing, marketing manag...
#
#                                                 text
# 0  google cybersecurity network security python p...
# 1  google data analytics data analysis r programm...
# 2  google project management project management s...
# 3  ibm data science python programming data scien...
# 4  google digital marketing e commerce digital ma...

# %%
course['text'].iloc[0]
# Out:
# 'google cybersecurity network security python programming linux cloud computing algorithms audit computer programming computer security incident management cryptography databases leadership and management network architecture risk management sql'

# %%
target_role = input('Enter a role: ').strip()
assert target_role in role_skills, f"'{target_role}' is not in the role list. Pick one of: {list(role_skills)}"
# Out:
# Enter a role: Data Scientist

# %%
target_role
# Out:
# 'Data Scientist'

# %%
current_skills = [s.strip().lower() for s in input('Enter your current skills (comma-separated): ').split(",") if s.strip()]
have = set(current_skills)
# Out:
# Enter your current skills (comma-separated): python

# %%
have
# Out:
# {'python'}

# %%
skill_gap = [s for s in role_skills[target_role] if s.lower() not in have]
query_text = " ".join(skill_gap)
print("skill_gap:", skill_gap)
# Out:
# skill_gap: ['statistics', 'machine learning', 'sql', 'data visualization', 'deep learning']

# %%
query_text
# Out:
# 'statistics machine learning sql data visualization deep learning'

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
tfidf=TfidfVectorizer(stop_words='english')

# %%
course_vector=tfidf.fit_transform(course['text']).toarray()

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
def recommend(query_text):
  query_vector=tfidf.transform([query_text])
  similarity=cosine_similarity(course_vector,query_vector).flatten()
  course_list=course.copy()
  course_list['score']=similarity
  course_list=course_list.sort_values(by='score',ascending=False)
  return course_list.head(10)

# %%
result_tfdif=recommend(query_text)

# %%
result_tfdif
# Out:
#      course_id                                              title  \
# 194        200                   Machine Learning on Google Cloud
# 7            9                                   Machine Learning
# 93          97                               IBM Machine Learning
# 519        525  Applying Machine Learning to your Data with Go...
# 288        294                  Deep Neural Networks with PyTorch
# 408        414       Introduction to Artificial Intelligence (AI)
# 149        155  Unsupervised Learning, Recommenders, Reinforce...
# 87          91                       Advanced Learning Algorithms
# 39          43                                 IBM AI Engineering
# 100        105               IBM Introduction to Machine Learning
#
#                                                 skills  \
# 194  [machine learning, applied machine learning, g...
# 7    [machine learning, machine learning algorithms...
# 93   [machine learning, machine learning algorithms...
# 519  [applied machine learning, big data, cloud com...
# 288  [human learning, machine learning, deep learni...
# 408  [algorithms, applied machine learning, artific...
# 149  [algorithms, machine learning, machine learnin...
# 87   [applied machine learning, machine learning, m...
# 39   [machine learning, deep learning, artificial n...
# 100  [machine learning, machine learning algorithms...
#
#                                                   text     score
# 194  machine learning on google cloud machine learn...  0.642587
# 7    machine learning machine learning machine lear...  0.635728
# 93   ibm machine learning machine learning machine ...  0.629923
# 519  applying machine learning to your data with go...  0.618981
# 288  deep neural networks with pytorch human learni...  0.614771
# 408  introduction to artificial intelligence ai alg...  0.606391
# 149  unsupervised learning recommenders reinforceme...  0.598838
# 87   advanced learning algorithms applied machine l...  0.595222
# 39   ibm ai engineering machine learning deep learn...  0.591767
# 100  ibm introduction to machine learning machine l...  0.590942

# %%
from sentence_transformers import SentenceTransformer,util

# %%
model=SentenceTransformer('all-MiniLM-L6-v2')
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# model.safetensors: reconstructing file:   0%|          |  0.00B / 90.9MB
# model.safetensors: downloading bytes:           |  0.00B
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
course_embedding=model.encode(course['text'].tolist(),convert_to_tensor=False)

# %%
#course_embedding

# %%
def recommend2(query_text):
  query_vector2=model.encode([query_text],convert_to_tensor=False)
  similarity=cosine_similarity(course_embedding,query_vector2).flatten()
  course_list=course.copy()
  course_list['score_embedding']=similarity
  course_list=course_list.sort_values(by='score_embedding',ascending=False)
  return course_list.head(10)

# %%
result_embedding=recommend2(query_text)

# %%
result_embedding
# Out:
#      course_id                                           title  \
# 366        372               Data Analytics for Lean Six Sigma
# 297        303         From Data to Insights with Google Cloud
# 214        220     Share Data Through the Art of Visualization
# 345        351                          1. 基礎知識：データはあらゆるところにある
# 420        426  Understanding and Visualizing Data with Python
# 48          52             Foundations: Data, Data, Everywhere
# 412        418           Sequences, Time Series and Prediction
# 23          27     Data Analysis and Visualization Foundations
# 379        385    Decisions, Decisions: Dashboards and Reports
# 143        149                  Introduction to Data Analytics
#
#                                                 skills  \
# 366  [probability & statistics, data visualization,...
# 297  [google cloud platform, cloud computing, sql, ...
# 214  [business communication, data analysis, data v...
# 345  [data analysis, business analysis, data visual...
# 420  [basic descriptive statistics, data analysis, ...
# 48   [data analysis, sql, data visualization, busin...
# 412  [machine learning, forecasting, tensorflow, ap...
# 23   [microsoft excel, data visualization, spreadsh...
# 379  [business intelligence, data model, data visua...
# 143  [data analysis, databases, python programming,...
#
#                                                   text  score_embedding
# 366  data analytics for lean six sigma probability ...         0.525871
# 297  from data to insights with google cloud google...         0.512695
# 214  share data through the art of visualization bu...         0.504352
# 345  1 data analysis business analysis data visuali...         0.498769
# 420  understanding and visualizing data with python...         0.491735
# 48   foundations data data everywhere data analysis...         0.491105
# 412  sequences time series and prediction machine l...         0.480311
# 23   data analysis and visualization foundations mi...         0.475694
# 379  decisions decisions dashboards and reports bus...         0.475412
# 143  introduction to data analytics data analysis d...         0.471046

# %%
def is_relevant(course_skills,skill_gap):
  course_skills=set(course_skills)
  skill_gap=set(skill_gap)
  return len(course_skills & skill_gap)>0

# %%
def precision_at_k(recommendations,skill_gap,k):
  relevant=0
  for _,row in recommendations.head(k).iterrows():
    if is_relevant(row['skills'],skill_gap):
      relevant+=1

  return relevant/k

# %%
skill_gap
# Out:
# ['statistics',
#  'machine learning',
#  'sql',
#  'data visualization',
#  'deep learning']

# %%
precisiontfdif=precision_at_k(result_tfdif,skill_gap,10)
print(precisiontfdif)
# Out:
# 1.0

# %%
precision_embedding=precision_at_k(result_embedding,skill_gap,10)
print(precision_embedding)
# Out:
# 1.0

# %%
def evaluate_role(target_role, current_skills, k=10):
    have = {s.strip().lower() for s in current_skills}
    skill_gap = [s for s in role_skills[target_role] if s.lower() not in have]
    query_text = " ".join(skill_gap)

    tfidf_recs = recommend(query_text)
    emb_recs   = recommend2(query_text)

    p_tfidf = precision_at_k(tfidf_recs, skill_gap, k)
    p_emb   = precision_at_k(emb_recs,  skill_gap, k)

    print(f"\n=== {target_role} | have={current_skills} ===")
    print("skill gap:", skill_gap)
    print("TF-IDF top-5:", tfidf_recs['title'].head(5).tolist())
    print("Embed  top-5:", emb_recs['title'].head(5).tolist())
    print(f"Precision@{k} -> TF-IDF={p_tfidf:.2f}  Embedding={p_emb:.2f}")
    return {"role": target_role, "p_tfidf": p_tfidf, "p_emb": p_emb}

scenarios = [
    ("Data Scientist", ["python"]),
    ("Data Analyst",   ["excel"]),
    ("NLP Engineer",   ["python", "machine learning"]),
]

rows = [evaluate_role(r, s) for r, s in scenarios]
import pandas as pd
pd.DataFrame(rows)
# Out:
# === Data Scientist | have=['python'] ===
# skill gap: ['statistics', 'machine learning', 'sql', 'data visualization', 'deep learning']
# TF-IDF top-5: ['Machine Learning on Google Cloud', 'Machine Learning', 'IBM Machine Learning', 'Applying Machine Learning to your Data with Google Cloud', 'Deep Neural Networks with PyTorch']
# Embed  top-5: ['Data Analytics for Lean Six Sigma', 'From Data to Insights with Google Cloud', 'Share Data Through the Art of Visualization', '1. 基礎知識：データはあらゆるところにある', 'Understanding and Visualizing Data with Python']
# Precision@10 -> TF-IDF=1.00  Embedding=1.00
#
# === Data Analyst | have=['excel'] ===
# skill gap: ['sql', 'statistics', 'data visualization', 'python']
# TF-IDF top-5: ['Data Visualization with Python', 'SQL für Data Science', 'Data Analysis and Visualization Foundations', 'Statistics for Data Science with Python', 'Understanding and Visualizing Data with Python']
# Embed  top-5: ['Understanding and Visualizing Data with Python', 'Data Visualization with Python', 'Python Packages for Data Science', 'Get Started with Python', 'Python and Statistics for Financial Analysis']
# Precision@10 -> TF-IDF=1.00  Embedding=1.00
#
# === NLP Engineer | have=['python', 'machine learning'] ===
# skill gap: ['deep learning', 'nlp', 'statistics']
# TF-IDF top-5: ['NLP: Twitter Sentiment Analysis', 'Deep Neural Networks with PyTorch', 'Neural Networks and Deep Learning', 'AI for Medicine', 'IBM Machine Learning']
# Embed  top-5: ['Natural Language Processing with Attention Models', 'Natural Language Processing', 'Generative AI Fundamentals', 'Introduction to Machine Learning', 'Generative AI with Large Language Models']
# Precision@10 -> TF-IDF=0.90  Embedding=0.40
#              role  p_tfidf  p_emb
# 0  Data Scientist      1.0    1.0
# 1    Data Analyst      1.0    1.0
# 2    NLP Engineer      0.9    0.4

# %%
rows
# Out:
# [{'role': 'Data Scientist', 'p_tfidf': 1.0, 'p_emb': 1.0},
#  {'role': 'Data Analyst', 'p_tfidf': 1.0, 'p_emb': 1.0},
#  {'role': 'NLP Engineer', 'p_tfidf': 0.9, 'p_emb': 0.4}]

# %%
eval_table = pd.DataFrame({"method":["TF-IDF","Embedding"], "precision":[precisiontfdif, precision_embedding]})
winner = "Embedding" if precision_embedding>= precisiontfdif else "TF-IDF"
print(eval_table.to_string(index=False)); print("winner:", winner)
# A single user at k=10 can tie at 1.0 - evaluate several roles & k values for real discrimination.
eval_table.plot.bar(x="method", y="precision", legend=False)
plt.title("Which recommender is better?"); plt.ylabel("precision"); plt.ylim(0,1.05); plt.show()
# Out:
#    method  precision
#    TF-IDF        1.0
# Embedding        1.0
# winner: Embedding

# %%
def make_roadmap(current_skills, target_role, skill_gap, best_recs):
    # Uses Groq if GROQ_API_KEY is set; otherwise returns a simple offline list.
    course_list = "\n".join(f"- {t}" for t in best_recs["title"].head(8))
    api_key = os.environ.get("GROQ_API_KEY")
    if api_key:
        try:
            from groq import Groq
            prompt = (
                f"You are helping a learner plan their upskilling.\n\n"
                f"Current skills: {', '.join(current_skills) or 'none'}\n"
                f"Target role: {target_role}\n"
                f"Skills they still need (the gap): {', '.join(skill_gap)}\n\n"
                f"Recommended courses - use ONLY these, do not invent any:\n{course_list}\n\n"
                "Write a month-by-month learning roadmap that uses ONLY the courses above, "
                "orders foundational skills before advanced ones, one short sentence per course, "
                "realistic over ~6-8 months, ending with a line that this is a SUGGESTED order, "
                "not a verified prerequisite plan."
            )
            resp = Groq(api_key=api_key).chat.completions.create(
                model="openai/gpt-oss-120b",
                messages=[{"role": "user", "content": prompt}])
            return resp.choices[0].message.content, True
        except Exception as e:
            print("Groq call failed, using offline sample:", e)
    lines = [f"Suggested roadmap toward {target_role} (offline sample):", ""]
    lines += [f"- Month {i}: {t}" for i, t in enumerate(best_recs["title"].head(8), 1)]
    lines += ["", "This is a SUGGESTED order, not a verified prerequisite plan."]
    return "\n".join(lines), False

best_recs = result_embedding if winner == "Embedding" else result_tfdif
roadmap_text, used_llm = make_roadmap(current_skills, target_role, skill_gap, best_recs)
print(("LIVE (Groq)" if used_llm else "OFFLINE sample") + " roadmap:\n")
print(roadmap_text)
# Out:
# LIVE (Groq) roadmap:
#
# **Month 1 – Getting comfortable with data concepts**
# - *Foundations: Data, Data, Everywhere* – Learn what data is, how it’s collected, and why it matters.
# - *1. 基礎知識：データはあらゆるところにある* – Gain a basic, multilingual perspective on the ubiquity of data.
#
# **Month 2 – Building statistical fundamentals**
# - *Data Analytics for Lean Six Sigma* – Master core statistical ideas (mean, variance, hypothesis testing) used in analytics.
# - *Data Analysis and Visualization Foundations* – Practice turning raw numbers into meaningful summaries and simple charts.
#
# **Month 3 – Visualising data with Python**
# - *Understanding and Visualizing Data with Python* – Apply pandas, matplotlib, and seaborn to explore datasets programmatically.
# - *Share Data Through the Art of Visualization* – Learn design principles that make visual stories clear and compelling.
#
# **Month 4 – Working with databases & cloud‑based tools**
# - *From Data to Insights with Google Cloud* – Write SQL queries, load data into BigQuery, and extract insights on a cloud platform.
#
# **Month 5 – Introductory machine‑learning & time‑series**
# - *Sequences, Time Series and Prediction* – Explore forecasting techniques, basic regression, and an introduction to neural‑network‑based predictors.
#
# **Month 6 – Consolidating and applying the skill set**
# - Review and combine the previous courses by completing a cap‑stone project: clean a dataset, perform statistical analysis, visualise results in Python, query additional data via SQL/BigQuery, and build a simple predictive model (e.g., time‑series forecast).
#
# **Month 7‑8 – Optional deep‑learning focus & portfolio building**
# - Use the time‑series and prediction concepts from *Sequences, Time Series and Prediction* to experiment with deeper neural‑network models (e.g., LSTM) on your own, documenting the process in a portfolio piece.
#
# ---
#
# *This is a SUGGESTED order, not a verified prerequisite plan.*

# %%
import gradio as gr

# FIX: keep the "skills" column so precision_at_k can read it (M6 needs it).
def _recommend(scores, k):
    top = scores.argsort()[::-1][:k]
    recs = course.loc[top, ["course_id", "title", "skills"]].copy()
    recs["score"] = scores[top].astype(float).round(3)
    recs["rank"] = range(1, len(recs) + 1)
    return recs[["rank", "course_id", "title", "score", "skills"]].reset_index(drop=True)

def run(target_role, current_skills, k):
    have = {s.lower() for s in (current_skills or [])}
    gap = [s for s in role_skills[target_role] if s.lower() not in have]              # M3
    if not gap:
        note = f"You already have every skill {target_role} needs. Try another role."
        empty = pd.DataFrame(columns=["rank","course_id","title","score"])
        return note, empty, empty, "", ""
    q = " ".join(gap)
    tf = _recommend(cosine_similarity(tfidf.transform([q]),course_vector).flatten(), k)     # M4
    em = _recommend(cosine_similarity(model.encode([q]), course_embedding).flatten(), k)    # M5
    # FIX: precision_at_k takes 3 args (recommendations, skill_gap, k) - not 4.
    p_tf = precision_at_k(tf, gap, k)                                                  # M6
    p_em = precision_at_k(em, gap, k)                                                  # M6
    winner = "Embedding" if p_em >= p_tf else "TF-IDF"
    best = em if winner == "Embedding" else tf
    gap_md = f"**Skill gap:** {', '.join(gap)}"
    if abs(p_tf - p_em) < 1e-9:
        win_md = (f"**Tie** - both score precision = {p_tf:.2f}. The methods differ in "
                  "*which* courses they surface (keywords vs meaning).")
    else:
        win_md = f"**Winner: {winner}** - precision: TF-IDF {p_tf:.2f} vs Embedding {p_em:.2f}"
    roadmap, _ = make_roadmap(list(have), target_role, gap, best)                      # M7
    roadmap = "  \n".join(line for line in roadmap.splitlines() if line.strip())
    # trim the helper "skills" column before showing the tables
    show = ["rank", "course_id", "title", "score"]
    return gap_md, tf[show], em[show], win_md, roadmap

# Force light mode so everyone sees the same UI regardless of their browser's dark setting.
_css = """
:root, html.dark, .dark {
  color-scheme: light !important;
  --bg-dark: #f8fafc !important; --col-dark: #1e293b !important;
  --body-background-fill: #f8fafc !important; --body-text-color: #1e293b !important;
  --background-fill-primary: #ffffff !important; --background-fill-secondary: #f1f5f9 !important;
  --block-background-fill: #eef2fb !important; --input-background-fill: #ffffff !important;
  --border-color-primary: #dbe3f2 !important; --input-border-color: #cdd7ea !important;
  --table-even-background-fill: #ffffff !important; --table-odd-background-fill: #f4f7fd !important;
  --neutral-900: #eef2fb !important; --neutral-950: #ffffff !important;
}
html, body, .gradio-container { background: #ffffff !important; color: #1e293b !important; }
.block { box-shadow: 0 1px 2px rgba(15,23,42,.05) !important; }
.token { background: #dbe4ff !important; color: #312e81 !important;
         border: 1px solid #c3cffb !important; border-radius: 8px !important; }
.token .token-remove, .token-remove { color: #4f46e5 !important; background: transparent !important; }
"""
with gr.Blocks(title="Course Recommender", css=_css) as demo:
    gr.Markdown("# 🎓 Course Recommender & Career Roadmap\nPick a role and the skills you already have.")
    with gr.Row():
        role_in = gr.Dropdown(list(role_skills), value="Data Scientist", label="Target role")
        skills_in = gr.Dropdown(sorted({s for v in role_skills.values() for s in v}),
                                value=["python"], multiselect=True, label="Skills you already have")
        k_in = gr.Slider(5, 15, value=10, step=1, label="Top-k")
    go = gr.Button("Get recommendations & roadmap", variant="primary")
    gap_out = gr.Markdown()
    with gr.Row():
        tfidf_out = gr.Dataframe(label="TF-IDF (baseline)", interactive=False)
        embed_out = gr.Dataframe(label="Embedding (semantic)", interactive=False)
    winner_out = gr.Markdown()
    roadmap_out = gr.Markdown()
    go.click(run, [role_in, skills_in, k_in],
             [gap_out, tfidf_out, embed_out, winner_out, roadmap_out])

# share=True is what gives you the public link in Colab.
demo.launch(share=True)
# Out:
# /tmp/ipykernel_521/718425666.py:56: UserWarning: The parameters have been moved from the Blocks constructor to the launch() method in Gradio 6.0: css. Please pass these parameters to launch() instead.
#   with gr.Blocks(title="Course Recommender", css=_css) as demo:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://10967db5676e1aa33e.gradio.live
#
# This share link is temporary and will last for up to 1 week (best effort). For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://10967db5676e1aa33e.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
